# %%
from IPython.display import display, Latex
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# %%
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})

# %%
elias24c = fits.open("/home/alexxruzza/Downloads/Elias24_continuum.fits")

# %%
elias24c

# %%
elias24c.info()
# Out:
# Filename: /home/alexxruzza/Downloads/Elias24_continuum.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      79   (3000, 3000, 1, 1)   float32

# %%
elias24c[0].header
# Out:
# SIMPLE  =                    T /Standard FITS
# BITPIX  =                  -32 /Floating point (32 bit)
# NAXIS   =                    4
# NAXIS1  =                 3000
# NAXIS2  =                 3000
# NAXIS3  =                    1
# NAXIS4  =                    1
# EXTEND  =                    T
# BSCALE  =   1.000000000000E+00 /PHYSICAL = PIXEL*BSCALE + BZERO
# BZERO   =   0.000000000000E+00
# BMAJ    =   1.020931224856E-05
# BMIN    =   9.518654810058E-06
# BPA     =   8.161357879639E+01
# BTYPE   = 'Intensity'
# OBJECT  = 'Elias_24'
#
# BUNIT   = 'Jy/beam '           /Brightness (pixel) unit
# RADESYS = 'ICRS    '
# LONPOLE =   1.800000000000E+02
# LATPOLE =  -2.427041666667E+01
# PC1_1   =   1.000000000000E+00
# PC2_1   =   0.000000000000E+00
# PC3_1   =   0.000000000000E+00
# PC4_1   =   0.000000000000E+00
# PC1_2   =   0.000000000000E+00
# PC2_2   =   1.000000000000E+00
# PC3_2   =   0.000000000000E+00
# PC4_2   =   0.000000000000E+00
# PC1_3   =   0.000000000000E+00
# PC2_3   =   0.000000000000E+00
# PC3_3   =   1.000000000000E+00
# PC4_3   =   0.000000000000E+00
# PC1_4   =   0.000000000000E+00
# PC2_4   =   0.000000000000E+00
# PC3_4   =   0.000000000000E+00
# PC4_4   =   1.000000000000E+00
# CTYPE1  = 'RA---SIN'
# CRVAL1  =   2.466002916667E+02
# CDELT1  =  -8.333333333333E-07
# CRPIX1  =   1.501000000000E+03
# CUNIT1  = 'deg     '
# CTYPE2  = 'DEC--SIN'
# CRVAL2  =  -2.427041666667E+01
# CDELT2  =   8.333333333333E-07
# CRPIX2  =   1.501000000000E+03
# CUNIT2  = 'deg     '
# CTYPE3  = 'FREQ    '
# CRVAL3  =   2.319430148430E+11
# CDELT3  =   3.191897042979E+10
# CRPIX3  =   1.000000000000E+00
# CUNIT3  = 'Hz      '
# CTYPE4  = 'STOKES  '
# CRVAL4  =   1.000000000000E+00
# CDELT4  =   1.000000000000E+00
# CRPIX4  =   1.000000000000E+00
# CUNIT4  = '        '
# PV2_1   =   0.000000000000E+00
# PV2_2   =   0.000000000000E+00
# RESTFRQ =   2.312000000000E+11 /Rest Frequency (Hz)
# SPECSYS = 'LSRK    '           /Spectral reference frame
# ALTRVAL =  -9.634526215708E+05 /Alternate frequency reference value
# ALTRPIX =   1.000000000000E+00 /Alternate frequency reference pixel
# VELREF  =                  257 /1 LSR, 2 HEL, 3 OBS, +256 Radio
# COMMENT casacore non-standard usage: 4 LSD, 5 GEO, 6 SOU, 7 GAL
# TELESCOP= 'ALMA    '
# OBSERVER= 'lperez  '
# DATE-OBS= '2015-07-21T22:46:02.688001'
# TIMESYS = 'UTC     '
# OBSRA   =   2.466002916667E+02
# OBSDEC  =  -2.427041666667E+01
# OBSGEO-X=   2.225142180269E+06
# OBSGEO-Y=  -5.440307370349E+06
# OBSGEO-Z=  -2.481029851874E+06
# OBJECT  = 'Elias_24'
# TELESCOP= 'ALMA    '
# INSTRUME= 'ALMA    '
# DISTANCE=   0.000000000000E+00
# DATE    = '2018-06-03T02:39:20.296000' /Date FITS file was written
# ORIGIN  = 'CASA 5.1.1-5'

# %%
dd = elias24c[0].data

# %%
from matplotlib.colors import LogNorm
plt.imshow(dd[0][0])
plt.colorbar()

# %%
eliasgas = fits.open("/home/alexxruzza/Downloads/Elias24_CO.fits")
egd = eliasgas[0].data

# %%
plt.imshow(egd[0][0])
